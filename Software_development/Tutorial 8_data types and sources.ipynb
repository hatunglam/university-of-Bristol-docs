# %% [markdown]
# # EMATM0048: Software Development Programming and Algorithms (SDPA)
# # `Tutorial - Web Scraping`

# %%
import requests # library to handle requests
import pandas as pd
import requests
import folium # plotting library
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# %% [markdown]
# ## Example 3 (advanced):

# %% [markdown]
# ### <font color= 'blue'> Question: </font>: Explore trending venues in your area

# %%
# define URL for trending vebues in london
address = 'Bristol'

# %%
url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "coffee",
  	"near": "Bristol,UK",
    #adding popularity and other needed information, check all fields here 
    #https://location.foursquare.com/developer/reference/response-fields
    "fields":"name,geocodes,popularity"
}

headers = {
    "Accept": "application/json",
    #your API key in the above screenshot
    "Authorization": "fsq3AT4h2SjhPIGBYfMa8fk9g6Mj7oqpUs8Cwur/pq4VyKc="
}

response = requests.request("GET", url, params=params, headers=headers)
print(response.text)
#Display the results
results = response.json()["results"]
# Out:
# {"results":[{"geocodes":{"main":{"latitude":51.455181,"longitude":-2.593114},"roof":{"latitude":51.455181,"longitude":-2.593114}},"name":"Full Court Press","popularity":0.9919012289743444},{"geocodes":{"main":{"latitude":51.453748,"longitude":-2.596502},"roof":{"latitude":51.453748,"longitude":-2.596502}},"name":"The Hatter","popularity":0.9973381661663929},{"geocodes":{"drop_off":{"latitude":51.455446,"longitude":-2.600694},"main":{"latitude":51.45533,"longitude":-2.600682},"roof":{"latitude":51.45533,"longitude":-2.600682}},"name":"Sotiris Bakery","popularity":0.917341564252138},{"geocodes":{"drop_off":{"latitude":51.45001,"longitude":-2.597376},"main":{"latitude":51.450072,"longitude":-2.597371},"roof":{"latitude":51.450072,"longitude":-2.597371}},"name":"Society Café","popularity":0.9852749617715354},{"geocodes":{"main":{"latitude":51.451247,"longitude":-2.592931},"roof":{"latitude":51.451247,"longitude":-2.592931}},"name":"Spicer & Cole","popularity":0.9840289969983576},{"geocodes":{"drop_off":{"latitude":51.446604,"longitude":-2.599265},"main":{"latitude":51.446648,"longitude":-2.59939},"roof":{"latitude":51.446648,"longitude":-2.59939}},"name":"Little Victories","popularity":0.9794415812425666},{"geocodes":{"main":{"latitude":51.455748,"longitude":-2.582192},"roof":{"latitude":51.455748,"longitude":-2.582192}},"name":"25A Old Market","popularity":0.9866058786883389},{"geocodes":{"main":{"latitude":51.463721,"longitude":-2.589967},"roof":{"latitude":51.463721,"longitude":-2.589967}},"name":"The Crafty Egg","popularity":0.973948009288101},{"geocodes":{"main":{"latitude":51.45529,"longitude":-2.618408},"roof":{"latitude":51.45529,"longitude":-2.618408}},"name":"Primrose Cafe","popularity":0.9685677068584697},{"geocodes":{"drop_off":{"latitude":51.475193,"longitude":-2.591154},"main":{"latitude":51.475102,"longitude":-2.591029},"roof":{"latitude":51.475102,"longitude":-2.591029}},"name":"Bakers and Co","popularity":0.9135187177889789}],"context":{"geo_bounds":{"circle":{"center":{"latitude":51.45523,"longitude":-2.59665},"radius":7129}}}}

# %%
#Convert Json to dataframe
dataframe = pd.json_normalize(results)

dataframe
# Out:
#                name  popularity  geocodes.main.latitude  \
# 0  Full Court Press    0.991901               51.455181
# 1        The Hatter    0.997338               51.453748
# 2    Sotiris Bakery    0.917342               51.455330
# 3      Society Café    0.985275               51.450072
# 4     Spicer & Cole    0.984029               51.451247
# 5  Little Victories    0.979442               51.446648
# 6    25A Old Market    0.986606               51.455748
# 7    The Crafty Egg    0.973948               51.463721
# 8     Primrose Cafe    0.968568               51.455290
# 9     Bakers and Co    0.913519               51.475102
#
#    geocodes.main.longitude  geocodes.roof.latitude  geocodes.roof.longitude  \
# 0                -2.593114               51.455181                -2.593114
# 1                -2.596502               51.453748                -2.596502
# 2                -2.600682               51.455330                -2.600682
# 3                -2.597371               51.450072                -2.597371
# 4                -2.592931               51.451247                -2.592931
# 5                -2.599390               51.446648                -2.599390
# 6                -2.582192               51.455748                -2.582192
# 7                -2.589967               51.463721                -2.589967
# 8                -2.618408               51.455290                -2.618408
# 9                -2.591029               51.475102                -2.591029
#
#    geocodes.drop_off.latitude  geocodes.drop_off.longitude
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                   51.455446                    -2.600694
# 3                   51.450010                    -2.597376
# 4                         NaN                          NaN
# 5                   51.446604                    -2.599265
# 6                         NaN                          NaN
# 7                         NaN                          NaN
# 8                         NaN                          NaN
# 9                   51.475193                    -2.591154

# %% [markdown]
# ## We will assume that venues with popularity >0.8 is ternding

# %%
trending_venues_df= dataframe[dataframe["popularity"]>0.8]
trending_venues_df
# Out:
#                name  popularity  geocodes.main.latitude  \
# 0  Full Court Press    0.991901               51.455181
# 1        The Hatter    0.997338               51.453748
# 2    Sotiris Bakery    0.917342               51.455330
# 3      Society Café    0.985275               51.450072
# 4     Spicer & Cole    0.984029               51.451247
# 5  Little Victories    0.979442               51.446648
# 6    25A Old Market    0.986606               51.455748
# 7    The Crafty Egg    0.973948               51.463721
# 8     Primrose Cafe    0.968568               51.455290
# 9     Bakers and Co    0.913519               51.475102
#
#    geocodes.main.longitude  geocodes.roof.latitude  geocodes.roof.longitude  \
# 0                -2.593114               51.455181                -2.593114
# 1                -2.596502               51.453748                -2.596502
# 2                -2.600682               51.455330                -2.600682
# 3                -2.597371               51.450072                -2.597371
# 4                -2.592931               51.451247                -2.592931
# 5                -2.599390               51.446648                -2.599390
# 6                -2.582192               51.455748                -2.582192
# 7                -2.589967               51.463721                -2.589967
# 8                -2.618408               51.455290                -2.618408
# 9                -2.591029               51.475102                -2.591029
#
#    geocodes.drop_off.latitude  geocodes.drop_off.longitude
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                   51.455446                    -2.600694
# 3                   51.450010                    -2.597376
# 4                         NaN                          NaN
# 5                   51.446604                    -2.599265
# 6                         NaN                          NaN
# 7                         NaN                          NaN
# 8                         NaN                          NaN
# 9                   51.475193                    -2.591154

# %%
#Getting lat and long for any location, pass the name, postice and get log, lat
address = 'Bristol City Centre'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 51.4539545 -2.5972859

# %%
#Visualize trending venues
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco

# add the trending venues as blue circle markers
for lat, lng, label in zip(trending_venues_df['geocodes.main.latitude'], trending_venues_df['geocodes.main.longitude'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26045c55be4737f37b9ab0d21d97e23a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26045c55be4737f37b9ab0d21d97e23a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26045c55be4737f37b9ab0d21d97e23a = L.map(
#                 &quot;map_26045c55be4737f37b9ab0d21d97e23a&quot;,
#                 {
#                     center: [51.4539545, -2.5972859],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae23aab1c3a1704cb5031dbfcd30227e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ae23aab1c3a1704cb5031dbfcd30227e.addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_0f8815b8474e2921c79dd62bf11a9fe6 = L.circleMarker(
#                 [51.455181, -2.593114],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_27136ec751c750298296e87dde79584b = L.circleMarker(
#                 [51.453748, -2.596502],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_697742aad236e0cf5e4781196cc0d768 = L.circleMarker(
#                 [51.45533, -2.600682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_101343a45169d6a88b54a406bc4f6536 = L.circleMarker(
#                 [51.450072, -2.597371],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_3bb052033c3d4d133d80480485193e92 = L.circleMarker(
#                 [51.451247, -2.592931],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_2c64e10c8375cc4db52f05c65c75556d = L.circleMarker(
#                 [51.446648, -2.59939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26045c55be4737f37b9ab0d21d97e23a);
#
#
#             var circle_marker_fcce0481adf604d17a5de8c4e5b269fe = L.circleMarker(
#                 [51.455748, -2.582192],
#                 {&quot;bubblingMouseEvents&quo

# %% [markdown]
# # Part B: HTML based scraping

# %% [markdown]
# ### <font color= 'Blue'> Question: </font>
#
# Extract cities in the UK from information in tables on this website
# https://en.wikipedia.org/wiki/List_of_cities_in_the_United_Kingdom

# %%
import pandas as pd
from bs4 import BeautifulSoup
url_link= 'https://en.wikipedia.org/wiki/List_of_cities_in_the_United_Kingdom'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0'})
UKdata = pd.read_html(r.text)
print(f'Extracted {len(UKdata)} table/s')
UKdata[0]
# Out:
# Extracted 5 table/s
# /var/folders/sg/td2g432d4_q96v_4dnz198hc0000gq/T/ipykernel_17732/2714644644.py:5: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   UKdata = pd.read_html(r.text)
#                                           De facto[e]  \
#                                                  City
# 0                                              London
# 1                                         Westminster
# 2                                          Birmingham
# 3                                               Leeds
# 4   Glasgow32 (Scots: Glesga) (Scottish Gaelic: Gl...
# ..                                                ...
# 71  Armagh[ab] (Irish: Ard Mhacha) (Ulster-Scots: ...
# 72                                             Bangor
# 73                                              Wells
# 74                         St Asaph (Welsh: Llanelwy)
# 75                         St Davids (Welsh: Tyddewi)
#
#                                                                   \
#           Statistical region           Year granted or confirmed
# 0                     London                "time immemorial"[g]
# 1                     London                                1540
# 2              West Midlands                            1889[21]
# 3   Yorkshire and the Humber                                1893
# 4                   Scotland  mid-18th century[12] (Burgh: 1492)
# ..                       ...                                 ...
# 71          Northern Ireland                                1994
# 72                     Wales                   "time immemorial"
# 73        South West England                   "time immemorial"
# 74                     Wales                                2012
# 75                     Wales                                1994
#
#                                De jure[f]  \
#                                City[3][1]
# 0                       City of London[h]
# 1                  City of Westminster[i]
# 2                   City of Birmingham[j]
# 3                        City of Leeds[k]
# 4                                 Glasgow
# ..                                    ...
# 71                                    NaN
# 72                    Bangor community[k]
# 73                        Wells parish[k]
# 74                  St Asaph community[s]
# 75  St Davids and the Cathedral Close[ac]
#
#
#                                   City council status            Population
# 0                   Sui generis and ceremonial county     12,156 (2023)[19]
# 1                                      London borough    213,119 (2023)[19]
# 2                                Metropolitan borough  1,171,467 (2023)[19]
# 3                                Metropolitan borough    829,417 (2023)[19]
# 4                                        Council area    620,700 (2022)[24]
# ..                                                ...                   ...
# 71  Represented on Armagh City, Banbridge and Crai...    16,310 (2021)[106]
# 72                                          Community    15,060 (2021)[107]
# 73                                       Civil parish    11,145 (2021)[108]
# 74                                          Community     3,485 (2021)[109]
# 75                                          Community     1,751 (2021)[113]
#
# [76 rows x 6 columns]

# %% [markdown]
# ## <font color= "blue">Question:</font>
# - Extract "Leave a Reply" title from this article
# -  Extract all links on the page

# %% [markdown]
# ## <font color= "Green"> Answer:</font>

# %%
web_url = 'https://www.luckytailsalpacafarm.co.uk/'
re = requests.get(web_url)
print('Status code\n', response.status_code)
print('\n--\n')
print('Content of the website\n', response.content[:2000])
# Out:
# Status code
#  200
#
# --
#
# Content of the website
#  b'{"results":[{"geocodes":{"main":{"latitude":51.455181,"longitude":-2.593114},"roof":{"latitude":51.455181,"longitude":-2.593114}},"name":"Full Court Press","popularity":0.9919012289743444},{"geocodes":{"main":{"latitude":51.453748,"longitude":-2.596502},"roof":{"latitude":51.453748,"longitude":-2.596502}},"name":"The Hatter","popularity":0.9973381661663929},{"geocodes":{"drop_off":{"latitude":51.455446,"longitude":-2.600694},"main":{"latitude":51.45533,"longitude":-2.600682},"roof":{"latitude":51.45533,"longitude":-2.600682}},"name":"Sotiris Bakery","popularity":0.917341564252138},{"geocodes":{"drop_off":{"latitude":51.45001,"longitude":-2.597376},"main":{"latitude":51.450072,"longitude":-2.597371},"roof":{"latitude":51.450072,"longitude":-2.597371}},"name":"Society Caf\xc3\xa9","popularity":0.9852749617715354},{"geocodes":{"main":{"latitude":51.451247,"longitude":-2.592931},"roof":{"latitude":51.451247,"longitude":-2.592931}},"name":"Spicer & Cole","popularity":0.9840289969983576},{"geocodes":{"drop_off":{"latitude":51.446604,"longitude":-2.599265},"main":{"latitude":51.446648,"longitude":-2.59939},"roof":{"latitude":51.446648,"longitude":-2.59939}},"name":"Little Victories","popularity":0.9794415812425666},{"geocodes":{"main":{"latitude":51.455748,"longitude":-2.582192},"roof":{"latitude":51.455748,"longitude":-2.582192}},"name":"25A Old Market","popularity":0.9866058786883389},{"geocodes":{"main":{"latitude":51.463721,"longitude":-2.589967},"roof":{"latitude":51.463721,"longitude":-2.589967}},"name":"The Crafty Egg","popularity":0.973948009288101},{"geocodes":{"main":{"latitude":51.45529,"longitude":-2.618408},"roof":{"latitude":51.45529,"longitude":-2.618408}},"name":"Primrose Cafe","popularity":0.9685677068584697},{"geocodes":{"drop_off":{"latitude":51.475193,"longitude":-2.591154},"main":{"latitude":51.475102,"longitude":-2.591029},"roof":{"latitude":51.475102,"longitude":-2.591029}},"name":"Bakers and Co","popularity":0.9135187177889789}],"context":{"geo_bounds":{"'

# %%
#Q1
soup_object = BeautifulSoup(re.content)
soup_object.find_all("h2")[0]
# Out:
# <h2 class="font_2 wixui-rich-text__text" style="font-size:24px; line-height:1.2em; text-align:center;"><span class="color_2 wixui-rich-text__text"><span class="wixui-rich-text__text" style="font-size:24px;"><span class="wixui-rich-text__text" style="letter-spacing:0em;"><span class="wixui-rich-text__text" style="font-family:lulo-clean-w01-one-bold,sans-serif;">Donkey Experiences</span></span></span></span></h2>

# %%
## Q2: 
for link in soup_object.find_all('a', href=True):
    print(link['href'])
# Out:
# https://fareharbor.com/embeds/book/luckytailsalpacafarm/items/576928/?full-items=yes&flow=470673
# https://www.luckytailsalpacafarm.co.uk
# https://www.luckytailsalpacafarm.co.uk/gift-vouchers
# https://www.luckytailsalpacafarm.co.uk/walks
# https://www.luckytailsalpacafarm.co.uk/adoptions
# https://www.luckytailsalpacafarm.co.uk/meerkats
# https://www.luckytailsalpacafarm.co.uk/our-boys
# https://www.luckytailsalpacafarm.co.uk/about-5
# https://www.luckytailsalpacafarm.co.uk/care-farm
# https://www.luckytailsalpacafarm.co.uk/blog
# https://www.luckytailsalpacafarm.co.uk/faq
# https://www.luckytailsalpacafarm.co.uk/cafe
# https://www.luckytailsalpacafarm.co.uk/care-home-visits
# https://www.luckytailsalpacafarm.co.uk
# https://www.luckytailsalpacafarm.co.uk/cart-page
# https://www.facebook.com/sarahbooth722
# https://www.instagram.com/luckytailsalpacas
# https://www.tiktok.com/@lucky.tails.alpacas
# https://fareharbor.com/embeds/book/luckytailsalpacafarm/?full-items=yes&flow=472922
# https://fareharbor.com/embeds/book/luckytailsalpacafarm/?full-items=yes&flow=470673
# https://www.luckytailsalpacafarm.co.uk
# https://www.luckytailsalpacafarm.co.uk
# https://www.luckytailsalpacafarm.co.uk
# https://fareharbor.com/embeds/book/luckytailsalpacafarm/?full-items=yes&flow=472922
# ./#comp-kb3c3vx2
# ./#comp-kb3c3vxu
# ./#comp-kb3c3vy12
# mailto:lucky.tails.alpacas@gmail.com
# mailto:lucky.tails.alpacas@gmail.com
# https://fareharbor.com/embeds/book/luckytailsalpacafarm/?full-items=yes&flow=1031769
